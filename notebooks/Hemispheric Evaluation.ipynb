# %%
import os
import sys

sys.path.append('..')
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

import torch
import numpy as np
import random
import pylab as plt
import tqdm

from coronal_diffusion import dataset, models, sampler, utils, constants
from coronal_diffusion import visualization_tools as vt

import config

import importlib
importlib.reload(sampler)
# Out:
# /home/dedasilv/.micromamba/envs/coronal-diffusion-modeling/lib/python3.11/site-packages/ai/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# <module 'coronal_diffusion.sampler' from '/home/dedasilv/coronal-diffusion-modeling/notebooks/../coronal_diffusion/sampler.py'>

# %%
os.chdir('..')
print('Current directory is:', os.getcwd())
# Out:
# Current directory is: /home/dedasilv/coronal-diffusion-modeling

# %%
sampling_data = sampler.load_sampling_data()

# %%
lats = np.arange(-90, 90, 2)
lons = np.arange(-180, 180, 2)

# %% [markdown]
# # Test Leading/Trailing Polarity

# %%
context = (50, 50, 10, 10, -1, 1),
img, (G, H) = sampler.sample(sampling_data, weights_file='checkpoints/experiment54-hemi_16.pth', context=context, method='ddim')
# Out:
# Denoising Step 5000
# Fitting spherical harmonics (45)

# %%
plt.figure(figsize=(12, 4))
plt.pcolor(lons, lats, img[0])
plt.colorbar()

# %%
context = (50, 50, 10, 10, 1, -1),
img, (G, H) = sampler.sample(sampling_data, weights_file='checkpoints/experiment54-hemi_16.pth', context=context, method='ddim')
# Out:
# Denoising Step 5000
# Fitting spherical harmonics (45)

# %%
plt.figure(figsize=(12, 4))
plt.pcolor(lons, lats, img[0])
plt.colorbar()

# %% [markdown]
# # SSN Solar Cycle Test

# %%
context = (0, 0, 5, 5, 1, -1),
img, (G, H) = sampler.sample(sampling_data, weights_file='checkpoints/experiment54-hemi_16.pth', context=context, method='ddim')
# Out:
# Denoising Step 5000
# Fitting spherical harmonics (45)

# %%
plt.figure(figsize=(12, 4))
plt.pcolor(lons, lats, img[0])
plt.colorbar()

# %%
context = (50, 50, 15, 15, 1, -1),
img, (G, H) = sampler.sample(sampling_data, weights_file='checkpoints/experiment54-hemi_16.pth', context=context, method='ddim')
# Out:
# Denoising Step 5000
# Fitting spherical harmonics (45)

# %%
plt.figure(figsize=(12, 4))
plt.pcolor(lons, lats, img[0])
plt.colorbar()

# %% [markdown]
# # Hemispheric Latitude Test

# %%
context = (5, 5, 25, 25, 1, -1),
img, (G, H) = sampler.sample(sampling_data, weights_file='checkpoints/experiment54-hemi_16.pth', context=context, method='ddim')
# Out:
# Denoising Step 5000
# Fitting spherical harmonics (45)

# %%
plt.figure(figsize=(12, 4))
plt.pcolor(lons, lats, img[0])
plt.axhline(25, color='red')
plt.axhline(-25, color='red')
plt.colorbar()

# %%
context = (5, 5, 5, 5, 1, -1),
img, (G, H) = sampler.sample(sampling_data, weights_file='checkpoints/experiment54-hemi_16.pth', context=context, method='ddim')
# Out:
# Denoising Step 5000
# Fitting spherical harmonics (45)

# %%
plt.figure(figsize=(12, 4))
plt.pcolor(lons, lats, img[0])
plt.axhline(5, color='red')
plt.axhline(-5, color='red')
plt.colorbar()
